# %%
# !pip install opencv-python-headless
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/python/3.12.1/lib/python3.12/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opencv-python-headless) (2.2.6)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Load an image
img = cv2.imread('car_green_screen.jpg')

# %%
# Transform the image into a grayscale format
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Implement the Canny edge detection technique
edges=cv2.Canny(gray, 100, 200)

# %%
# Plot the processed image
plt.imshow(edges)
# cv2.waitKey(0)
