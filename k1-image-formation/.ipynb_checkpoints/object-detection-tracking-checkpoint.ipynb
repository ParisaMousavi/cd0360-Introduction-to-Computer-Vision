# %% [markdown]
# # Feature-Based Object Representation Using DAISY Descriptors

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-image) (2.2.6)
# Requirement already satisfied: scipy>=1.11.4 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-image) (1.16.0)
# Requirement already satisfied: networkx>=3.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-image) (3.3)
# Requirement already satisfied: pillow>=10.1 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-image) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-image) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scikit-image) (0.4)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import cv2
import numpy as np
from skimage.feature import daisy
# Load the image in grayscale
image = cv2.imread('result_image.png',
    cv2.IMREAD_GRAYSCALE)
# Compute DAISY feature descriptors
descs, descs_img = daisy(image,
    step = 180,
    radius = 58,
    rings = 2,
    histograms = 6,
    orientations = 8,
    visualize=True)
# Convert the descriptors image from grayscale to RGB
descs_img = cv2.cvtColor(descs_img,
                         cv2.COLOR_GRAY2RGB)
# Show the image with DAISY descriptors
plt.imshow(descs_img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 16
#       8 descs, descs_img = daisy(image,
#       9     step = 180,
#      10     radius = 58,
#    (...)     13     orientations = 8,
#      14     visualize=True)
#      15 # Convert the descriptors image from grayscale to RGB
# ---> 16 descs_img = cv2.cvtColor(descs_img,
#      17                          cv2.COLOR_GRAY2RGB)
#      18 # Show the image with DAISY descriptors
#      19 plt.imshow(descs_img)
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-15:Bad number of channels) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<1>; VDcn = cv::impl::{anonymous}::Set<3, 4>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = cv::impl::<unnamed>::NONE; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 3

# %% [markdown]
# # Template Matching Using OpenCV

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# Load the image and the template
image = cv2.imread('ananas-supermarkt.jpg',
    0)
template = cv2.imread('ananas.jpg',
    0)
w, h = template.shape[: : -1]
# Perform template matching
res = cv2.matchTemplate(image,
    template,
    cv2.TM_CCOEFF_NORMED)
# Set a threshold and find where
# the matching result exceeds it
threshold = 0.215
loc = np.where(res >= threshold)
# Create a copy of the original image
# in color to draw rectangles
color_image = cv2.cvtColor(image,
    cv2.COLOR_GRAY2BGR)
# Draw rectangles around the matched regions
for pt in zip(* loc[::-1]):
    cv2.rectangle(color_image,
        pt,
        (pt[0] + 2*w, pt[1] + 2*h),
        (25, 25, 25),
        2)
plt.imshow(color_image)
plt.title('Detected ananas')
plt.show()

# %% [markdown]
# # Graph-Based Object Representation

# %%
import face_recognition
# Load the jpg file into a numpy array
image = face_recognition.load_image_file({your_image.jpg})
# Find all the faces in the image
face_locations = face_recognition.face_locations(image)
# If you have a GPU and CUDA installed,
# you can use the CNN model which is more accurate
# face_locations = face_recognition.face_locations(image, model={cnn})
# Display the results
for face_location in face_locations:
    # Print each face’s location
    top, right, bottom, left = face_location
    print(f"A face is located at pixel location Top: {top}, Left: {left}, Bottom: {bottom}, Right: {right}")
# You can also use face_encodings to recognize faces
face_encodings = face_recognition.face_encodings(image,
    face_locations)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import face_recognition
#       2 # Load the jpg file into a numpy array
#       3 image = face_recognition.load_image_file({your_image.jpg})
#
# ModuleNotFoundError: No module named 'face_recognition'
