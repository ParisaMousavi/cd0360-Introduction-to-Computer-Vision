# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
original_image = cv2.imread('data/images/segment-1231623110026745648_480_000_500_000_with_camera_labels_38 copy.png')
plt.imshow(original_image)
